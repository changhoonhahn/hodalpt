# %% [markdown]
# # Check the Sobol Sequence for the cosmological parameters

# %%
import numpy as np
import matplotlib.pyplot as plt
import corner

# %%
sobol = np.loadtxt("../../bin/sense/cosmology_alpt_sobol2048.dat", skiprows=1)

# %%
sobol
# Out:
# array([[0.27241179, 0.06257472, 0.82256511, 0.82138267, 0.71917569],
#        [0.37143781, 0.03725422, 0.51406927, 1.03089909, 0.94346091],
#        [0.43867897, 0.05436793, 0.72550401, 0.94052519, 0.847394  ],
#        ...,
#        [0.43899443, 0.0430189 , 0.58017807, 0.84618777, 0.68641901],
#        [0.37117729, 0.06606142, 0.76564846, 1.13695228, 0.77936576],
#        [0.27247324, 0.03388439, 0.67101968, 0.91532947, 0.95838826]],
#       shape=(2048, 5))

# %%
fig = corner.corner(sobol, labels=[r'$\Omega_m$', r'$\Omega_b$', '$h$', '$n_s$', r'$\sigma_8$'])
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
plt.scatter(sobol[:,0], sobol[:,1], s=1)

# %% [markdown]
# Looks good!
