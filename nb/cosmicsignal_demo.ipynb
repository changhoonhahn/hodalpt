# %% [markdown]
# # quick demo of `hodalpt.sims.alpt` module

# %%
import numpy as np 
import matplotlib.pyplot as plt
from hodalpt.sims import alpt as CS

# %% [markdown]
# # run CS to generate ALPT DM

# %%
fconfig = '/Users/hahnchanghoon/projects/CosmicSignal4SimBIG/boxes/config_file.ini'
outdir = '/Users/hahnchanghoon/data/simbig/quijote/fiducial/1/alpt'

# %%
xyz = CS.CSbox_alpt(fconfig, outdir, seed=0, make_ics=True, silent=False)
# Out:
# Computing and writing out delta IC
# Computing displacement fields at z=0.5
# Compiled with MULTITHREAD support, with 14 threads
#  >>> web-on: initialising settings....
#
# ---> attention: N1= 256
# z_input.par
# ---> attention: redshift= 0
#
#
#  >>> starting web-on  ...
#
#  >>> web-on initialising cosmological model....
#
# number of chosen redshift snapshots = 1
# ... writing file posx.dat
# ... writing file posy.dat
# ... writing file posz.dat
# ... writing file posorx.dat
# ... writing file posory.dat
# ... writing file posorz.dat
# ... writing file posor0x.dat
# ... writing file posor0y.dat
# ... writing file posor0z.dat
# ... reading file Quijote_ICs_delta_z127_n256_CIC.DAT
# ... writing file deltaICOM0.317OL0.683G256V1000.0.dat
# ... writing file auxreal.dat
# ... writing file auxim.dat
#  >>> dump power-spectrum in : pk_deltaICOM0.317OL0.683G256V1000.0.dat
# -->  sample velocity;  z_min, z_max: 0.5  0.5
# ... writing file VEZELDx.dat
# ... writing file VEZELDy.dat
# ... writing file VEZELDz.dat
# -->  calculate values for: 1 snapshots
# redshift=0.5, growth=0.76823
# ... reading file TWOLPTG256V1000.0.dat
# ... reading file kernelr5.000000.dat
# ... reading file kernelr5.000000.dat
# ... reading file posx.dat
# ... reading file posy.dat
# ... reading file posz.dat
# ... writing file deltaBOXOM0.317OL0.683G256V1000.0_ALPTrs5.000z0.500.dat
# ... writing file auxreal.dat
# ... writing file auxim.dat
#  >>> dump power-spectrum in : pk_deltaBOXOM0.317OL0.683G256V1000.0_ALPTrs5.000z0.500.dat
# ... writing file BOXposxOM0.317OL0.683G256V1000.0_ALPTrs5.000z0.500.dat
# ... writing file BOXposyOM0.317OL0.683G256V1000.0_ALPTrs5.000z0.500.dat
# ... writing file BOXposzOM0.317OL0.683G256V1000.0_ALPTrs5.000z0.500.dat
# ... writing file PSIxz0.500.dat
# ... writing file PSIyz0.500.dat
# ... writing file PSIzz0.500.dat
# starting cosmic web classification...
# Solving Poisson equation in Fourier space ...
# ... done!
#
# unassigned cells in the cosmic web: 0
# ... writing file Tweb_OM0.317OL0.683G256V1000.0_ALPTrs5.000z0.500.dat
# Cosmic web classification done!
# starting cosmic web classification...
# unassigned cells in the cosmic web: 0
# ... writing file TwebDelta_OM0.317OL0.683G256V1000.0_ALPTrs5.000z0.500.dat
# Cosmic web classification done!
# ... writing file STWODELTAG256V1000.0.dat
# starting cosmic web classification...
# unassigned cells in the cosmic web: 0
# ... writing file TwebDelta2_OM0.317OL0.683G256V1000.0_ALPTrs5.000z0.500.dat
# Cosmic web classification done!
# Solving Poisson equation in Fourier space ...
# ... done!
#
# ... writing file STWOPHIG256V1000.0.dat
# ... reading file VEZELDx.dat
# ... reading file VEZELDy.dat
# ... reading file VEZELDz.dat
# ... reading file PSIxz0.500.dat
# ... reading file PSIyz0.500.dat
# ... reading file PSIzz0.500.dat
# ... writing file VExz0.500.dat
# ... writing file VEyz0.500.dat
# ... writing file VEzz0.500.dat
# ... reading file BOXposxOM0.317OL0.683G256V1000.0_ALPTrs5.000z0.500.dat
# ... reading file BOXposyOM0.317OL0.683G256V1000.0_ALPTrs5.000z0.500.dat
# ... reading file BOXposzOM0.317OL0.683G256V1000.0_ALPTrs5.000z0.500.dat
# ... writing file VExEULz0.500.dat
# ... writing file VEyEULz0.500.dat
# ... writing file VEzEULz0.500.dat
# starting cosmic web classification...
# unassigned cells in the cosmic web: 0
# ... writing file Vweb_OM0.317OL0.683G256V1000.0_ALPTrs5.000z0.500.dat
# Cosmic web classification done!
# Finished because write_box=true!
#
#  >>> web-on  finished.

# %%
x, y, z = xyz.T
zslice = (z > 100) & (z < 110)
plt.scatter(x[zslice], y[zslice], s=0.1)

# %% [markdown]
# # run CS bias model

# %%
# arbitrary parameters
theta_gal = {
    'alpha': 1.9230, 
    'beta': 2.0253, 
    'dth': -0.7889, 
    'rhoeps': 14.6874, 
    'eps': 0.5616, 
    'nmean': 3.3e-4}
theta_rsd = {
    'bv': 0.7289, 
    'bb': 1.1652,
    'betarsd': 1.3136, 
    'gamma': 0.4944}

# %%
xyz_g = CS.CSbox_galaxy(theta_gal, theta_rsd, '/Users/hahnchanghoon/data/simbig/quijote/fiducial/1/alpt/', silent=False)
# Out:
# OM0.317OL0.683G256V1000.0_ALPTrs5.000z0.500.dat
# Omega_m 0.317000
# Reading input ...
# Getting number counts via parametric bias ...
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# Number counts diagnostics (min, max, mean):  0.0 14.0 0.019699573516845703
# Preparing galaxy positions ...
# Sampling galaxy positions ...
# -->Find starting indices ...
# -->Start loop over cells of the mesh ...
# apply RSD ...

# %%
zslice = (z > 100) & (z < 110)
plt.scatter(x[zslice], y[zslice], s=0.1, c='k')

x0, y0, z0 = xyz_g.T
zslice0 = (z0 > 100) & (z0 < 110)
plt.scatter(x0[zslice0], y0[zslice0], s=1, c='r')
